# %%
# Importing Libraries / Dependencies
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# Loading the Data (.csv file)
df = pd.read_csv('C:\\Users\\anjali kumari\\Desktop\\Amazon Sales data.csv')

# Data Exploration & Cleaning
print("Data Shape:", df.shape)
print("First 5 Rows:")
print(df.head())
print("Column Names:", df.columns)
print("Data Information:")
df.info()

print("Null Values in Dataset:")
print(pd.isnull(df).sum())
print("Duplicate Values in Dataset:")
print(df.duplicated().value_counts())
print("Descriptive Statistics:")
print(df.describe())

print("Descriptive Statistics for Selected Columns:")
print(df[['Units Sold','Unit Price','Unit Cost','Total Revenue','Total Cost','Total Profit']].describe())

# Exporting Dataframe into csv file (Clean data)
df.to_csv('C:\\Users\\anjali kumari\\Desktop\\Clean_Sales_Data.csv',index=False)
# Out:
# Data Shape: (100, 14)
# First 5 Rows:
#                               Region                Country        Item Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub-Saharan Africa                 Rwanda  Office Supplies
#
#   Sales Channel Order Priority Order Date   Order ID  Ship Date  Units Sold  \
# 0       Offline              H  5/28/2010  669165933  6/27/2010        9925
# 1        Online              C  8/22/2012  963881480  9/15/2012        2804
# 2       Offline              L   5/2/2014  341417157   5/8/2014        1779
# 3        Online              C  6/20/2014  514321792   7/5/2014        8102
# 4       Offline              L   2/1/2013  115456712   2/6/2013        5062
#
# ...
